# %% [markdown]
# <a href="https://colab.research.google.com/github/eyadasn111-hue/NEWRDP/blob/main/ColabSteam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Tap this if you play on Mobile { display-mode: "form" }
# %%html
<b>Ensure this audio is playing to prevent colab from shutting down, then start ColabSteam below</b><br/>
<audio autoplay="" src="https://github.com/kmille36/Colab-Cloud-Gaming/raw/refs/heads/main/silence.m4a" loop controls>
# Out:
# <b>Ensure this audio is playing to prevent colab from shutting down, then start ColabSteam below</b><br/>
# <audio autoplay="" src="https://github.com/kmille36/Colab-Cloud-Gaming/raw/refs/heads/main/silence.m4a" loop controls>

# %%
#@title 🌐 Colab Region Check  { display-mode: "form" }

import subprocess
import time
from google.colab import runtime

# Get region
region = subprocess.check_output(
    "curl -s ipinfo.io | grep region | cut -d\\\" -f4",
    shell=True
).decode().strip()

print(f"Your current region: {region}")

try:
    print("Automatically keeping this runtime in 15 seconds... (Press Ctrl+C to unassign)")
    for i in range(15, 0, -1):
        print(f"{i}...", end="", flush=True)
        time.sleep(1)
    print("\nKeeping current runtime...")

except KeyboardInterrupt:
    print("\nCtrl+C detected — unassigning runtime...")
    runtime.unassign()

# %%
#@title 🖥️ Colab Cloud Game Mode by NT.Hai { display-mode: "form" }
Mount_Google_Drive = True #@param {type:"boolean"}

if Mount_Google_Drive:
    from google.colab import drive
    drive.mount('/content/drive')
    print("✅ Drive mounted.")
else:
    print("⛔ Skipped mount.")

# !wget -q https://github.com/kmille36/Colab-Cloud-Gaming/raw/refs/heads/main/ColabSteam && chmod +x ColabSteam && ./ColabSteam
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Drive mounted.
# Colab GPU Gaming by fb.com/thuong.hai.581 v2.2.0 FIX-NETWORK-LAG. Sunshine, Steam, Heroic
# Preparing installation files. Please wait...
# Running: tailscale up
# Tailscale IP: 100.125.11.12
# Connected Tailscale region: Los
# User and root pass are 123456.
# Do you want to restore the backup? (y/n): n
# Skipped restore.
# Sit back and relax. Installing... (2m)
# Enter Moonlight PIN: 9256
# Running: curl -u admin:admin -X POST -k https://localhost:47990/api/password -H "Content-Type: application/json" -d '{"currentUsername":"admin","currentPassword":"admin","newUsername":"admin","newPassword":"admin","confirmNewPassword":"admin"}'
# {
#     "status": "true"
# }
# Running: curl -u admin:admin -X POST -k https://localhost:47990/api/pin -H "Content-Type: application/json" -d '{"pin":"9256","name":"my-moonlight-device"}'
# {
#     "status": "true"
# }
# Setup completed. Press pause colab to initiate backup or exit.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
# Steam is running.
